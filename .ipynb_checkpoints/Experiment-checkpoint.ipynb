# %%
from globals import * 
import fileinput
import re

input_file = open("globals_backup.py", "r")
import fileinput
import re

for line in fileinput.input():
    line = re.sub(r'globals()\\['test']*', r'\1', line.rstrip())
    print(line)

# %%
## Scale Value Experiment

# %%
set_var('EPOCHS', 50)

# %%
set_var('SCALE_OUTPUT', 100)
# !python speedchallenge.py --mode train
# Out:
# 2021-01-04 02:32:13.287329: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Speed Challenge
# 2021-01-04 02:32:15.854981: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-04 02:32:15.855316: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-04 02:32:15.855375: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: UNKNOWN ERROR (-1)
# 2021-01-04 02:32:15.855400: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e01c8c19c2aa): /proc/driver/nvidia/version does not exist
# 2021-01-04 02:32:15.857953: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "sequential"
# ...

# %%
set_var('SCALE_OUTPUT', 10)
# !python speedchallenge.py --mode train
# Out:
# 2021-01-04 02:33:02.851931: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Speed Challenge
# 2021-01-04 02:33:05.391358: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-04 02:33:05.391569: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-04 02:33:05.391611: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: UNKNOWN ERROR (-1)
# 2021-01-04 02:33:05.391654: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e01c8c19c2aa): /proc/driver/nvidia/version does not exist
# 2021-01-04 02:33:05.392984: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "sequential"
# ...

# %%
set_var('SCALE_OUTPUT', 1)
# !python speedchallenge.py --mode train
# Out:
# 2021-01-04 02:33:07.531195: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Speed Challenge
# 2021-01-04 02:33:11.057640: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-04 02:33:11.058311: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-04 02:33:11.058395: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: UNKNOWN ERROR (-1)
# 2021-01-04 02:33:11.058512: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e01c8c19c2aa): /proc/driver/nvidia/version does not exist
# 2021-01-04 02:33:11.061310: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "sequential"
# ...
