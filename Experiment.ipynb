# %%
from globals import *
from globals import global_var

# %% [markdown]
# ## OutPUT Scale Value Experiment

# %%
# !python speedchallenge.py --mode train --set_var_num 'SCALE_OUTPUT' 100
# Out:
# 2021-01-04 04:15:02.383169: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ['SCALE_OUTPUT', '100']
# Speed Challenge
# 2021-01-04 04:15:04.720846: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-04 04:15:04.721102: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-04 04:15:04.721147: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: UNKNOWN ERROR (-1)
# 2021-01-04 04:15:04.721172: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e01c8c19c2aa): /proc/driver/nvidia/version does not exist
# 2021-01-04 04:15:04.730197: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "sequential"
# ...

# %%
# !python speedchallenge.py --mode train --set_var_num 'SCALE_OUTPUT' 10
# Out:
# 2021-01-04 04:16:01.280254: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ['SCALE_OUTPUT', '10']
# Speed Challenge
# 2021-01-04 04:16:03.735803: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-04 04:16:03.736228: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-04 04:16:03.736279: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: UNKNOWN ERROR (-1)
# 2021-01-04 04:16:03.736331: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e01c8c19c2aa): /proc/driver/nvidia/version does not exist
# 2021-01-04 04:16:03.737402: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "sequential"
# ...

# %%
# !python speedchallenge.py --mode train  --set_var_num 'SCALE_OUTPUT' 1
# Out:
# 2021-01-04 04:17:00.114204: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ['SCALE_OUTPUT', '1']
# Speed Challenge
# 2021-01-04 04:17:02.442146: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-04 04:17:02.442395: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-04 04:17:02.442446: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: UNKNOWN ERROR (-1)
# 2021-01-04 04:17:02.442471: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e01c8c19c2aa): /proc/driver/nvidia/version does not exist
# 2021-01-04 04:17:02.443836: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "sequential"
# ...

# %% [markdown]
# ## Conclusion:
# Scaling does not make a difference
